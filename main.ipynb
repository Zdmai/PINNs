# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
no = np.load('./dataset/train/no/1.npy')[0]
sphere = np.load('./dataset/train/sphere/1.npy')[0]
vort = np.load('./dataset/train/vort/1.npy')[0]

# %%
plt.imshow(no, cmap='gray'), no.shape
# Out:
# (<matplotlib.image.AxesImage at 0x1384909e0>, (150, 150))

# %%
plt.imshow(sphere, cmap='gray')

# %%
plt.imshow(vort, cmap='gray')
