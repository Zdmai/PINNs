# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
no = np.load('./dataset/train/no/1.npy')[0]
no1 = np.load('./dataset/train/no/1.npy')
sphere = np.load('./dataset/train/sphere/1.npy')[0]
vort = np.load('./dataset/train/vort/1.npy')[0]

# %%
plt.imshow(no), no.shape
# Out:
# (<matplotlib.image.AxesImage at 0x118683940>, (150, 150))

# %%
plt.imshow(sphere)

# %%
plt.imshow(vort)

# %%
plt.imshow(no)

# %%
import torch.nn as nn
import torch

print(no1.shape)
no1 = torch.tensor(no1, dtype=torch.float32)
t = nn.Conv2d(1, 1, 8, padding='same', bias=False)
y = t(no1)
plt.imshow(y.detach()[0])
# Out:
# (1, 150, 150)
# /opt/homebrew/Caskroom/miniconda/base/envs/PINNs/lib/python3.9/site-packages/torch/nn/modules/conv.py:456: UserWarning: Using padding='same' with even kernel lengths and odd dilation may require a zero-padded copy of the input be created (Triggered internally at /private/var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_52h9q6gsr9/croot/pytorch-select_1707258249748/work/aten/src/ATen/native/Convolution.cpp:1041.)
#   return F.conv2d(input, weight, bias, self.stride,
